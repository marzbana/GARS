# %%
# !pip install git+https://github.com/marzbana/GARS.git
# Out:
# Collecting git+https://github.com/marzbana/GARS.git
#   Cloning https://github.com/marzbana/GARS.git to /tmp/pip-req-build-3scgexvq
#   Running command git clone --filter=blob:none --quiet https://github.com/marzbana/GARS.git /tmp/pip-req-build-3scgexvq
#   Resolved https://github.com/marzbana/GARS.git to commit 1f799d6160a0713509b5e8be946c4c2053af2d12
#   Preparing metadata (setup.py) ... done
# Collecting mxeval@ git+https://github.com/shubhamugare/mxeval.git (from syncode2==1)
#   Cloning https://github.com/shubhamugare/mxeval.git to /tmp/pip-install-75ta7b95/mxeval_80cdc371bde745d5be2de5189ebbb6ac
#   Running command git clone --filter=blob:none --quiet https://github.com/shubhamugare/mxeval.git /tmp/pip-install-75ta7b95/mxeval_80cdc371bde745d5be2de5189ebbb6ac
#   Resolved https://github.com/shubhamugare/mxeval.git to commit 590129d063c5e7d145e8b15a83f00ff20d69a189
#   Preparing metadata (setup.py) ... done
# Collecting syncode@ git+https://github.com/uiuc-focal-lab/syncode.git (from syncode2==1)
#   Cloning https://github.com/uiuc-focal-lab/syncode.git to /tmp/pip-install-75ta7b95/syncode_b656473ec00647ad817e27b3df3f89e0
#   Running command git clone --filter=blob:none --quiet https://github.com/uiuc-focal-lab/syncode.git /tmp/pip-install-75ta7b95/syncode_b656473ec00647ad817e27b3df3f89e0
#   Resolved https://github.com/uiuc-focal-lab/syncode.git to commit 5ec58cd2a34effa4196c6ed13e73f0480bbf45f3
#   Preparing metadata (setup.py) ... done
# Collecting fire (from syncode2==1)
#   Downloading fire-0.7.0.tar.gz (87 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 87.2/87.2 kB 3.7 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting interegular (from syncode2==1)
#   Downloading interegular-0.3.3-py37-none-any.whl.metadata (3.0 kB)
# Collecting regex==2023.8.8 (from syncode2==1)
#   Downloading regex-2023.8.8-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (40 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.9/40.9 kB 3.9 MB/s eta 0:00:00
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (from syncode2==1) (2.5.1+cu121)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from syncode2==1) (4.66.6)
# Collecting transformers==4.44.0 (from syncode2==1)
#   Downloading transformers-4.44.0-py3-none-any.whl.metadata (43 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.7/43.7 kB 3.4 MB/s eta 0:00:00
# Collecting datasets (from syncode2==1)
#   Downloading datasets-3.2.0-py3-none-any.whl.metadata (20 kB)
# Requirement already satisfied: jsonschema in /usr/local/lib/python3.10/dist-packages (from syncode2==1) (4.23.0)
# Collecting evaluate (from syncode2==1)
#   Downloading evaluate-0.4.3-py3-none-any.whl.metadata (9.2 kB)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers==4.44.0->syncode2==1) (3.16.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.23.2 in /usr/local/lib/python3.10/dist-packages (from transformers==4.44.0->syncode2==1) (0.26.3)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers==4.44.0->syncode2==1) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers==4.44.0->syncode2==1) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers==4.44.0->syncode2==1) (6.0.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers==4.44.0->syncode2==1) (2.32.3)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers==4.44.0->syncode2==1) (0.4.5)
# Collecting tokenizers<0.20,>=0.19 (from transformers==4.44.0->syncode2==1)
#   Downloading tokenizers-0.19.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.7 kB)
# Requirement already satisfied: pyarrow>=15.0.0 in /usr/local/lib/python3.10/dist-packages (from datasets->syncode2==1) (17.0.0)
# Collecting dill<0.3.9,>=0.3.0 (from datasets->syncode2==1)
#   Downloading dill-0.3.8-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from datasets->syncode2==1) (2.2.2)
# Collecting xxhash (from datasets->syncode2==1)
#   Downloading xxhash-3.5.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (12 kB)
# Collecting multiprocess<0.70.17 (from datasets->syncode2==1)
#   Downloading multiprocess-0.70.16-py310-none-any.whl.metadata (7.2 kB)
# Collecting fsspec<=2024.9.0,>=2023.1.0 (from fsspec[http]<=2024.9.0,>=2023.1.0->datasets->syncode2==1)
#   Downloading fsspec-2024.9.0-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from datasets->syncode2==1) (3.11.9)
# Requirement already satisfied: termcolor in /usr/local/lib/python3.10/dist-packages (from fire->syncode2==1) (2.5.0)
# Requirement already satisfied: attrs>=22.2.0 in /usr/local/lib/python3.10/dist-packages (from jsonschema->syncode2==1) (24.2.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.10/dist-packages (from jsonschema->syncode2==1) (2024.10.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.10/dist-packages (from jsonschema->syncode2==1) (0.35.1)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.10/dist-packages (from jsonschema->syncode2==1) (0.22.3)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch->syncode2==1) (4.12.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch->syncode2==1) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch->syncode2==1) (3.1.4)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.10/dist-packages (from torch->syncode2==1) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy==1.13.1->torch->syncode2==1) (1.3.0)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->syncode2==1) (2.4.4)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->syncode2==1) (1.3.1)
# Requirement already satisfied: async-timeout<6.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->syncode2==1) (4.0.3)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->syncode2==1) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->syncode2==1) (6.1.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->syncode2==1) (0.2.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->syncode2==1) (1.18.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->transformers==4.44.0->syncode2==1) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers==4.44.0->syncode2==1) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers==4.44.0->syncode2==1) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers==4.44.0->syncode2==1) (2024.8.30)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch->syncode2==1) (3.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets->syncode2==1) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets->syncode2==1) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets->syncode2==1) (2024.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas->datasets->syncode2==1) (1.16.0)
# Downloading regex-2023.8.8-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (771 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 771.9/771.9 kB 21.4 MB/s eta 0:00:00
# Downloading transformers-4.44.0-py3-none-any.whl (9.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.5/9.5 MB 118.2 MB/s eta 0:00:00
# Downloading datasets-3.2.0-py3-none-any.whl (480 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 480.6/480.6 kB 38.0 MB/s eta 0:00:00
# Downloading evaluate-0.4.3-py3-none-any.whl (84 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.0/84.0 kB 9.6 MB/s eta 0:00:00
# Downloading interegular-0.3.3-py37-none-any.whl (23 kB)
# Downloading dill-0.3.8-py3-none-any.whl (116 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 12.4 MB/s eta 0:00:00
# Downloading fsspec-2024.9.0-py3-none-any.whl (179 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 179.3/179.3 kB 18.2 MB/s eta 0:00:00
# Downloading multiprocess-0.70.16-py310-none-any.whl (134 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 11.8 MB/s eta 0:00:00
# Downloading tokenizers-0.19.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.6/3.6 MB 97.5 MB/s eta 0:00:00
# Downloading xxhash-3.5.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (194 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.1/194.1 kB 16.9 MB/s eta 0:00:00
# Building wheels for collected packages: syncode2, fire, mxeval, syncode
#   Building wheel for syncode2 (setup.py) ... done
#   Created wheel for syncode2: filename=syncode2-1-py3-none-any.whl size=5243 sha256=4746bd6578c4b79c68d08018786cbbb37c5f905436e92943ce9ddeacf4ec0b63
#   Stored in directory: /tmp/pip-ephem-wheel-cache-3n7x7g7b/wheels/dd/56/3b/35d07dcb958a74f4d354865f358cae660a9cebcfc3c2cbf950
#   Building wheel for fire (setup.py) ... done
#   Created wheel for fire: filename=fire-0.7.0-py3-none-any.whl size=114249 sha256=4faefccb6401bfb783905d5f741d5d8ef3d5dba3e147170bd31d06f9072f33e3
#   Stored in directory: /root/.cache/pip/wheels/19/39/2f/2d3cadc408a8804103f1c34ddd4b9f6a93497b11fa96fe738e
#   Building wheel for mxeval (setup.py) ... done
#   Created wheel for mxeval: filename=mxeval-1.0-py3-none-any.whl size=4426397 sha256=05b4f5eab865fb85b7fd21cd7a768d22f36482b97efc7e1a1169135c748be664
#   Stored in directory: /tmp/pip-ephem-wheel-cache-3n7x7g7b/wheels/3e/f5/a5/764e23ecae9b1b6d851d346ff94626f6c90e2ebdf1625b9617
#   Building wheel for syncode (setup.py) ... done
#   Created wheel for syncode: filename=syncode-0.1-py3-none-any.whl size=217942 sha256=3ff7af9b64e12d45550bd860e6f65269a7184659cd1dd7a1433b0faeb142537b
#   Stored in directory: /tmp/pip-ephem-wheel-cache-3n7x7g7b/wheels/d2/bb/65/3b47cdc986428be8c96c7a3678d13add9c8e452e46189921a7
# Successfully built syncode2 fire mxeval syncode
# Installing collected packages: xxhash, regex, interegular, fsspec, fire, dill, mxeval, multiprocess, tokenizers, transformers, datasets, syncode, evaluate, syncode2
#   Attempting uninstall: regex
#     Found existing installation: regex 2024.9.11
#     Uninstalling regex-2024.9.11:
#       Successfully uninstalled regex-2024.9.11
#   Attempting uninstall: fsspec
#     Found existing installation: fsspec 2024.10.0
#     Uninstalling fsspec-2024.10.0:
#       Successfully uninstalled fsspec-2024.10.0
#   Attempting uninstall: tokenizers
#     Found existing installation: tokenizers 0.20.3
#     Uninstalling tokenizers-0.20.3:
#       Successfully uninstalled tokenizers-0.20.3
#   Attempting uninstall: transformers
#     Found existing installation: transformers 4.46.3
#     Uninstalling transformers-4.46.3:
#       Successfully uninstalled transformers-4.46.3
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# gcsfs 2024.10.0 requires fsspec==2024.10.0, but you have fsspec 2024.9.0 which is incompatible.
# Successfully installed datasets-3.2.0 dill-0.3.8 evaluate-0.4.3 fire-0.7.0 fsspec-2024.9.0 interegular-0.3.3 multiprocess-0.70.16 mxeval-1.0 regex-2023.8.8 syncode-0.1 syncode2-1 tokenizers-0.19.1 transformers-4.44.0 xxhash-3.5.0

# %%
# **1. Import Necessary Libraries**
import torch
from syncode2 import SyncodeLogitsProcessor2
from syncode import Grammar
from transformers import AutoModelForCausalLM, AutoTokenizer, LogitsProcessorList, BitsAndBytesConfig
from datasets import load_dataset
from evaluate import load
import random
import re
from tqdm import tqdm

# %%
# **2. Setup Device**
device = 'cuda' if torch.cuda.is_available() else 'cpu'

# %%
# **3. Load the Model**
model_name = "stabilityai/stable-code-3b"
# Load tokenizer and model
tokenizer = AutoTokenizer.from_pretrained(model_name,padding_side='left')
model = AutoModelForCausalLM.from_pretrained(
       model_name,
       device_map="cuda",
       torch_dtype=torch.bfloat16,
    )
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/4.76k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/2.47M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/441 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/602 [00:00<?, ?B/s]
# model.safetensors.index.json:   0%|          | 0.00/29.4k [00:00<?, ?B/s]
# Downloading shards:   0%|          | 0/2 [00:00<?, ?it/s]
# model-00001-of-00002.safetensors:   0%|          | 0.00/4.98G [00:00<?, ?B/s]
# model-00002-of-00002.safetensors:   0%|          | 0.00/610M [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/111 [00:00<?, ?B/s]

# %%
special_tokens_dict = {}
if tokenizer.pad_token is None:
    special_tokens_dict['pad_token'] = '<pad>'
if tokenizer.eos_token is None:
    special_tokens_dict['eos_token'] = '</s>'

if special_tokens_dict:
    tokenizer.add_special_tokens(special_tokens_dict)
    model.resize_token_embeddings(len(tokenizer))

# Assign pad_token_id and eos_token_id
model.config.pad_token_id = tokenizer.pad_token_id
model.config.eos_token_id = tokenizer.eos_token_id

# Verify assignments
print("Pad token ID:", tokenizer.pad_token_id)  # Should be 0 for LLaMA
print("EOS token ID:", tokenizer.eos_token_id)  # Should be 2 for LLaMA
# Out:
# Pad token ID: 50296
# EOS token ID: 0

# %%
# **4. Initialize SynCode with Python Grammar**
grammar = Grammar(name='python')
syncode_logits_processor = SyncodeLogitsProcessor2(grammar=grammar, tokenizer=tokenizer, parse_output_only=False)
# Out:
# Creating DFA mask store for GPTNeoXTokenizerFast and python, may take more than 10 minutes. Caching at /content/cache/mask_stores/GPTNeoXTokenizerFast/grammar_mask_2631017962_50254.pkl.
# Ignore whitespace tokens is True
# 100%|██████████| 402/402 [21:53<00:00,  3.27s/it]

# %%
# **5. Define Sampling Parameters**
sampling_sizes = [50]
temperature = 0.7  # Adjust as per hyperparameter tuning
max_length = 512  # Adjust based on model capacity and dataset

# %%
# **6. Load Benchmark Dataset**

# Using HumanEval dataset
dataset = load_dataset("openai_humaneval")['test']
dataset_list = list(dataset)

random_problems = random.sample(dataset_list, 20)
# Out:
# README.md:   0%|          | 0.00/6.52k [00:00<?, ?B/s]
# test-00000-of-00001.parquet:   0%|          | 0.00/83.9k [00:00<?, ?B/s]
# Generating test split:   0%|          | 0/164 [00:00<?, ? examples/s]

# %%
# **7. Define Functions for Zero-shot and Two-shot Prompting**

def get_zero_shot_prompt(sample):
    return sample['prompt']

def get_two_shot_prompt(samples, current_sample):
    # Randomly select two samples for few-shot examples
    i = random.randint(0, len(samples) - 1)
    example = samples[i]
    prompt = f"""
    #EXAMPLE:
    {example['prompt']}
    #OUTPUT:
    {example['canonical_solution']}


    #PROBLEM:
    {current_sample['prompt']}
    """
    return prompt

# %%
# Convert dataset to list for easy sampling
dataset_samples = [sample for sample in dataset]

# %%
def extract_indented_block(code: str) -> str:
    """
    Extracts a block of text starting from a specified line in the code where
    each subsequent line is indented. Stops when a non-indented line is encountered.

    Parameters:
    - code (str): The full code as a string.
    - start_line_index (int): The index of the line to start extracting from (0-based).

    Returns:
    - str: The indented block of text.
    """
    # Split the code into lines
    lines = code.splitlines()

    # Initialize the indented block
    indented_block = []

    # Iterate through the lines starting from the given index
    for i in range(0, len(lines)):
        line = lines[i]
        if line.strip() == "":
            # Skip empty lines
            continue
        if not line.startswith(" "):  # Stop when a non-indented line is encountered
            break
        indented_block.append(line)

    # Join the indented lines into a single block
    return "\n".join(indented_block)

# %%
def grab_name(function_declaration):
  pattern = r'\bdef\s+([a-zA-Z_][a-zA-Z0-9_]*)\s*\('

  # Extract the function name
  match = re.search(pattern, function_declaration)
  if match:
      return match.group(1)  # Group 1 contains the function name
  else:
      print("No function name found")

# %%
# **8.1 Zero-shot Prompting**
results_zero = [[
    [] for _ in range(len(random_problems))
] for _ in range(len(sampling_sizes))]

test_cases = []

print("Running Zero-shot Prompting...")
# Enumerate to get both index and value from sampling_sizes
for i, num_samples in enumerate(sampling_sizes):
    syncode_logits_processor = SyncodeLogitsProcessor2(grammar=grammar, tokenizer=tokenizer, parse_output_only=False, num_samples=num_samples)
    for num, sample in enumerate(random_problems):
        print(f"Problem {num}")
        prompt1 = get_zero_shot_prompt(sample)
        prompt = [prompt1 for _ in range(num_samples)]
        function_name = grab_name(prompt1)
        test_cases.append(sample['test']+f'\ncheck({function_name})')

        # Tokenize prompt once
        inputs = tokenizer(prompt, return_tensors='pt').to(device)
        syncode_logits_processor.reset(prompt)

        # Generate multiple sequences at once
        with torch.no_grad():
            try:
                output = model.generate(
                    input_ids=inputs['input_ids'],
                    attention_mask=inputs['attention_mask'],
                    max_length=512,
                    do_sample=True,
                    temperature=temperature,
                    logits_processor=LogitsProcessorList([syncode_logits_processor]),
                    top_p=0.95,
                    num_return_sequences=1,
                    eos_token_id=tokenizer.eos_token_id,
                    pad_token_id=tokenizer.pad_token_id
                )
            except Exception as e:
                print(f"An error occurred during generation: {e}")
                output = None

        # Decode all returned sequences
        if output is not None:
            for seq_idx in range(num_samples):
                code3 = tokenizer.decode(output[seq_idx][inputs['input_ids'].shape[-1]:], skip_special_tokens=True)
                code3 = extract_indented_block(code3)
                code = prompt1 + '\n' + code3
                # Use i (the index of the sampling size), not num_samples
                results_zero[i][num].append(code)
# Out:
# Running Zero-shot Prompting...
# Problem 0
# Problem 1
# Problem 2
# Problem 3
# Problem 4
# Problem 5
# Problem 6
# Problem 7
# Problem 8
# Problem 9
# An error occurred during generation: max() arg is an empty sequence
# Problem 10
# Problem 11
# Problem 12
# Problem 13
# Problem 14
# Problem 15
# Problem 16
# Problem 17
# Problem 18
# Problem 19

# %%
os.environ["PYTORCH_CUDA_ALLOC_CONF"] = "expandable_segments:True"
import gc
gc.collect()
torch.cuda.empty_cache()

# %%
import os
os.environ["HF_ALLOW_CODE_EVAL"] = "1"

# %%
# Compute pass@k
results2= results_zero[0]

code_eval_metric = load("code_eval")

k_values = [1,5,10,20,50]
print("Evaluating generated code...")
pass_at_k, results3 = code_eval_metric.compute(
    references=test_cases,
    predictions=results2,
    k=k_values,
    num_workers=4,  # Adjust based on your system
    timeout=10.0,   # Adjust the timeout as needed
)

# Print the results
for k in k_values:
    print(f"Pass@{k}: {pass_at_k[f'pass@{k}'] * 100:.2f}%")
# Out:
# Downloading builder script:   0%|          | 0.00/9.18k [00:00<?, ?B/s]
# Downloading extra modules:   0%|          | 0.00/6.10k [00:00<?, ?B/s]
# Evaluating generated code...
# Pass@1: 16.84%
# Pass@5: 36.29%
# Pass@10: 46.92%
# Pass@20: 56.69%
# Pass@50: 63.16%

# %%
# **8.2 No syncode**
results_no = [[
    [] for _ in range(len(random_problems))
] for _ in range(len(sampling_sizes))]

print("Running Zero-shot Prompting...")
# Enumerate to get both index and value from sampling_sizes
for i, num_samples in enumerate(sampling_sizes):
    for num, sample in enumerate(random_problems):
        print(f"Problem {num}")
        prompt1 = get_zero_shot_prompt(sample)
        prompt = [prompt1 for _ in range(num_samples)]
        function_name = grab_name(prompt1)

        # Tokenize prompt once
        inputs = tokenizer(prompt, return_tensors='pt').to(device)
        # Generate multiple sequences at once
        with torch.no_grad():
            try:
                output = model.generate(
                    input_ids=inputs['input_ids'],
                    attention_mask=inputs['attention_mask'],
                    max_length=512,
                    do_sample=True,
                    temperature=temperature,
                    top_p=0.95,
                    num_return_sequences=1,
                    eos_token_id=tokenizer.eos_token_id,
                    pad_token_id=tokenizer.pad_token_id
                )
            except Exception as e:
                print(f"An error occurred during generation: {e}")
                output = None

        # Decode all returned sequences
        if output is not None:
            for seq_idx in range(num_samples):
                code3 = tokenizer.decode(output[seq_idx][inputs['input_ids'].shape[-1]:], skip_special_tokens=True)
                code3 = extract_indented_block(code3)
                code = prompt1 + '\n' + code3
                # Use i (the index of the sampling size), not num_samples
                results_no[i][num].append(code)
        gc.collect()
        torch.cuda.empty_cache()
# Out:
# Running Zero-shot Prompting...
# Problem 0
# Problem 1
# Problem 2
# Problem 3
# Problem 4
# Problem 5
# Problem 6
# Problem 7
# Problem 8
# Problem 9
# Problem 10
# Problem 11
# Problem 12
# Problem 13
# Problem 14
# Problem 15
# Problem 16
# Problem 17
# Problem 18
# Problem 19

# %%
# Compute pass@k
results2_no= results_no[0]

code_eval_metric = load("code_eval")

k_values = [1,5,10,20,50]
print("Evaluating generated code...")
pass_at_k, results3 = code_eval_metric.compute(
    references=test_cases,
    predictions=results2_no,
    k=k_values,
    num_workers=4,  # Adjust based on your system
    timeout=10.0,   # Adjust the timeout as needed
)

# Print the results
for k in k_values:
    print(f"Pass@{k}: {pass_at_k[f'pass@{k}'] * 100:.2f}%")
# Out:
# Evaluating generated code...
# Pass@1: 18.80%
# Pass@5: 42.09%
# Pass@10: 52.98%
# Pass@20: 62.72%
# Pass@50: 80.00%

# %%
# !pip install calflops
# Out:
# Collecting calflops
#   Downloading calflops-0.3.2-py3-none-any.whl.metadata (28 kB)
# Requirement already satisfied: accelerate>=0.22.0 in /usr/local/lib/python3.10/dist-packages (from calflops) (1.1.1)
# Requirement already satisfied: huggingface-hub>=0.16.4 in /usr/local/lib/python3.10/dist-packages (from calflops) (0.26.3)
# Requirement already satisfied: torch>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from calflops) (2.5.1+cu121)
# Requirement already satisfied: numpy<3.0.0,>=1.17 in /usr/local/lib/python3.10/dist-packages (from accelerate>=0.22.0->calflops) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from accelerate>=0.22.0->calflops) (24.2)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from accelerate>=0.22.0->calflops) (5.9.5)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.10/dist-packages (from accelerate>=0.22.0->calflops) (6.0.2)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.10/dist-packages (from accelerate>=0.22.0->calflops) (0.4.5)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.16.4->calflops) (3.16.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.16.4->calflops) (2024.9.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.16.4->calflops) (2.32.3)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.16.4->calflops) (4.66.6)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.16.4->calflops) (4.12.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.1.0->calflops) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.1.0->calflops) (3.1.4)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.10/dist-packages (from torch>=1.1.0->calflops) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy==1.13.1->torch>=1.1.0->calflops) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.1.0->calflops) (3.0.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.16.4->calflops) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.16.4->calflops) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.16.4->calflops) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.16.4->calflops) (2024.8.30)
# Downloading calflops-0.3.2-py3-none-any.whl (29 kB)
# Installing collected packages: calflops
# Successfully installed calflops-0.3.2

# %%
from calflops import calculate_flops
batch_size = 1
sequence_length = 128  # Typical length for inference
input_shape = (batch_size, sequence_length)

# Calculate FLOPs, MACs, and Params
flops, macs, params = calculate_flops(model=model,
                                      input_shape=(batch_size,sequence_length),
                                      transformer_tokenizer=tokenizer)
print(f"FLOPs: {flops}, MACs: {macs}, Params: {params}")
# Out:
# /usr/local/lib/python3.10/dist-packages/transformers/tokenization_utils_base.py:2905: FutureWarning: The `truncation_strategy` argument is deprecated and will be removed in a future version, use `truncation=True` to truncate examples to a max length. You can give a specific length with `max_length` (e.g. `max_length=45`) or leave max_length to None to truncate to the maximal input size of the model (e.g. 512 for Bert).  If you have pairs of inputs, you can give a specific truncation strategy selected among `truncation='only_first'` (will only truncate the first sentence in the pairs) `truncation='only_second'` (will only truncate the second sentence in the pairs) or `truncation='longest_first'` (will iteratively remove tokens from the longest sentence in the pairs).
#   warnings.warn(
# Asking to truncate to max_length but no maximum length is provided and the model has no predefined maximum length. Default to no truncation.
# We detected that you are passing `past_key_values` as a tuple and this is deprecated and will be removed in v4.43. Please use an appropriate `Cache` class (https://huggingface.co/docs/transformers/v4.41.3/en/internal/generation_utils#transformers.Cache)
# ------------------------------------- Calculate Flops Results -------------------------------------
# Notations:
# number of parameters (Params), number of multiply-accumulate operations(MACs),
# number of floating-point operations (FLOPs), floating-point operations per second (FLOPS),
# fwd FLOPs (model forward propagation FLOPs), bwd FLOPs (model backward propagation FLOPs),
# default model backpropagation takes 2.00 times as much computation as forward propagation.
#
# Total Training Params:                                                  2.8 B
# fwd MACs:                                                               341.29 GMACs
# fwd FLOPs:                                                              682.71 GFLOPS
# fwd+bwd MACs:                                                           1.02 TMACs
# fwd+bwd FLOPs:                                                          2.05 TFLOPS
#
# -------------------------------- Detailed Calculated FLOPs Results --------------------------------
# Each module caculated is listed after its name in the following order:
# params, percentage of total params, MACs, percentage of total MACs, FLOPS, percentage of total FLOPs
#
# Note: 1. A module can have torch.nn.module or torch.nn.functional to compute logits (e.g. CrossEntropyLoss).
#  They are not counted as submodules in calflops and not to be printed out. However they make up the difference between a parent's MACs and the sum of its submodules'.
# 2. Number of floating-point operations is a theoretical estimation, thus FLOPS computed using that could be larger than the maximum system throughput.
#
# StableLmForCausalLM(
#   2.8 B = 100% Params, 341.29 GMACs = 100% MACs, 682.71 GFLOPS = 100% FLOPs
#   (model): StableLmModel(
#     2.67 B = 95.39% Params, 324.81 GMACs = 95.17% MACs, 649.75 GFLOPS = 95.17% FLOPs
#     (embed_tokens): Embedding(128.76 M = 4.61% Params, 0 MACs = 0% MACs, 0 FLOPS = 0% FLOPs, 50297, 2560)
#     (layers): ModuleList(
#       (0-31): 32 x StableLmDecoderLayer(
#         79.31 M = 2.84% Params, 10.15 GMACs = 2.97% MACs, 20.3 GFLOPS = 2.97% FLOPs
#         (self_attn): StableLmSdpaAttention(
#           26.21 M = 0.94% Params, 3.36 GMACs = 0.98% MACs, 6.71 GFLOPS = 0.98% FLOPs
#           (q_proj): Linear(6.55 M = 0.23% Params, 838.86 MMACs = 0.25% MACs, 1.68 GFLOPS = 0.25% FLOPs, in_features=2560, out_features=2560, bias=False)
#           (k_proj): Linear(6.55 M = 0.23% Params, 838.86 MMACs = 0.25% MACs, 1.68 GFLOPS = 0.25% FLOPs, in_features=2560, out_features=2560, bias=False)
#           (v_proj): Linear(6.55 M = 0.23% Params, 838.86 MMACs = 0.25% MACs, 1.68 GFLOPS = 0.25% FLOPs, in_features=2560, out_features=2560, bias=False)
#           (o_proj): Linear(6.55 M = 0.23% Params, 838.86 MMACs = 0.25% MACs, 1.68 GFLOPS = 0.25% FLOPs, in_features=2560, out_features=2560, bias=False)
#           (attention_dropout): Dropout(0 = 0% Params, 0 MACs = 0% MACs, 0 FLOPS = 0% FLOPs, p=0.0, inplace=False)
#           (rotary_emb): StableLmRotaryEmbedding(0 = 0% Params, 0 MACs = 0% MACs, 0 FLOPS = 0% FLOPs)
#         )
#         (mlp): StableLmMLP(
#           53.08 M = 1.9% Params, 6.79 GMACs = 1.99% MACs, 13.59 GFLOPS = 1.99% FLOPs
#           (gate_proj): Linear(17.69 M = 0.63% Params, 2.26 GMACs = 0.66% MACs, 4.53 GFLOPS = 0.66% FLOPs, in_features=2560, out_features=6912, bias=False)
#           (up_proj): Linear(17.69 M = 0.63% Params, 2.26 GMACs = 0.66% MACs, 4.53 GFLOPS = 0.66% FLOPs, in_features=2560, out_features=6912, bias=False)
#           (down_proj): Linear(17.69 M = 0.63% Params, 2.26 GMACs = 0.66% MACs, 4.53 GFLOPS = 0.66% FLOPs, in_features=6912, out_features=2560, bias=False)
#           (act_fn): SiLU(0 = 0% Params, 0 MACs = 0% MACs, 884.74 KFLOPS = 0% FLOPs)
#         )
#         (input_layernorm): LayerNorm(5.12 K = 0% Params, 0 MACs = 0% MACs, 1.64 MFLOPS = 0% FLOPs, (2560,), eps=1e-05, elementwise_affine=True)
#         (post_attention_layernorm): LayerNorm(5.12 K = 0% Params, 0 MACs = 0% MACs, 1.64 MFLOPS = 0% FLOPs, (2560,), eps=1e-05, elementwise_affine=True)
#         (dropout): Dropout(0 = 0% Params, 0 MACs = 0% MACs, 0 FLOPS = 0% FLOPs, p=0.0, inplace=False)
#       )
#     )
#     (norm): LayerNorm(5.12 K = 0% Params, 0 MACs = 0% MACs, 1.64 MFLOPS = 0% FLOPs, (2560,), eps=1e-05, elementwise_affine=True)
#   )
#   (lm_head): Linear(128.76 M = 4.61% Params, 16.48 GMACs = 4.83% MACs, 32.96 GFLOPS = 4.83% FLOPs, in_features=2560, out_features=50297, bias=False)
# )
# ---------------------------------------------------------------------------------------------------
# FLOPs: 682.71 GFLOPS, MACs: 341.29 GMACs, Params: 2.8 B
